# %% [markdown]
# ### This notebook walks through how to load a video stimulus and its corresponding metadata.

# %%
import os
import json
from pprint import pprint

from IPython.display import Video

# %%
project_root = "/data/vision/oliva/scratch/blahner/BMD_tmp" #os.path.join("/your","local","project","path")
#video ID to load
#videos 1-1000 are from the training set, and videos 1001-1102 are from the testing set
video_ID = 500

#load the metadata file
with open(os.path.join(project_root,"derivatives","stimuli_metadata","annotations.json"), 'r') as f:
    metadata = json.load(f)

# %%
#display video metadata. The order of the dictionary fields does not matter.
#Read the metadata README and manuscript for an explanation of the metadata
pprint(metadata[f"{video_ID:04}"])
# Out:
# {'MiT_classID': ['213', '142', '142', '228', '254'],
#  'MiT_filename': 'bending/flickr-3-8-5-1-6-3-6-9-16538516369_2.mp4',
#  'MiT_url': 'https://data.csail.mit.edu/soundnet/actions3/bending/flickr-3-8-5-1-6-3-6-9-16538516369_2.mp4',
#  'PLACES365_classID': ['315', '315', '46', '329', '5'],
#  'THINGS_uniqueID': [['t-shirt', 'hat', 'drum'],
#                      ['bucket', 'paper', 'jeans'],
#                      ['hat', 'dress', 'beard'],
#                      ['arm', 'chair', '--'],
#                      ['hat', 'chair', 'microphone']],
#  'actions': ['dancing', 'performing', 'performing', 'stretching', 'cheering'],
#  'bmd_matrixfilename': 'vid_idx0500',
#  'memorability_decay': -0.0014334279115157274,
#  'memorability_score': 0.9083862026460859,
#  'objects': [['t-shirt', 'hat', 'drum'],
#              ['bucket', 'paper', 'jeans'],
#              ['hat', 'dress', 'beard'],
#              ['arm', 'chair', '--'],
#              ['hat', 'chair', 'microphone']],
#  'scenes': ['stage/indoor',
#             'stage/indoor',
#             'bazaar/indoor',
#             'television_studio',
#             'amphitheater'],
#  'set': 'train',
#  'spoken_transcription': 'A stage full of people and the people are performing '
#                          'and dancing around',
#  'text_descriptions': ['A man dancing on the stage in front of his friends',
#                        'A man with a paper in his mouth that hands it to '
#                        'another man.',
#                        'A smiling man performs something funny to an intimate '
#                        'audience',
#                        'A man with hay in his mouth and another wearing a '
#                        'cowboy hat',
#                        'A young man gestures surrounded by other young men and '
#                        'a large "27"']}

# %%
#display video mp4
Video(os.path.join(project_root, "derivatives", "stimuli_metadata", "mp4_h264", f"{video_ID:04}.mp4"), embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
